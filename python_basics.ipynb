# %%
print("welcome to data science")
# Out:
# welcome to data science

# %%
x=5
print(x)
print("Value of x is :" , x)
print(type(x))
# Out:
# 5
# Value of x is : 5
# <class 'int'>

# %%
x=5
y=4
print(x , y)
print("Value of x is :" , x)
print("Value of y is :" , y)
print("addition of them is :" , x*y)
print(type(x) , type(y))
# Out:
# 5 4
# Value of x is : 5
# Value of y is : 4
# addition of them is : 20
# <class 'int'> <class 'int'>

# %%
a="mak"
print(a)
print(type(a))
# Out:
# mak
# <class 'str'>

# %%
# Simple Calculator Program with Continuous Calculations

while True:
  try:
    # Get input from the user
    num1 = float(input("Enter the first number (or 'q' to quit): "))
    if str(num1).lower() == 'q':
      break
    num2 = float(input("Enter the second number: "))

    # Perform arithmetic operations
    addition = num1 + num2
    subtraction = num1 - num2
    multiplication = num1 * num2

    # Handle division by zero
    if num2 != 0:
      division = num1 / num2
    else:
      division = "Cannot divide by zero"

    # Display the results
    print(f"Addition: {addition}")
    print(f"Subtraction: {subtraction}")
    print(f"Multiplication: {multiplication}")
    print(f"Division: {division}")

  except ValueError:
    print("Invalid input. Please enter numbers or 'q' to quit.")
# Out:
# Enter the first number: 2
# Enter the second number: 6
# Addition: 8.0
# Subtraction: -4.0
# Multiplication: 12.0
# Division: 0.3333333333333333
